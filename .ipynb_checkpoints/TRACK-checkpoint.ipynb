# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import datetime

# %%
df = pd.read_csv('Toggl_time_entries_2022-01-01_to_2022-12-31 (1).csv')
df
# Out:
#               User                   Email  Client               Project  \
# 0     Johnspinkles  johnspinkles@gmail.com     NaN                 To-Do
# 1     Johnspinkles  johnspinkles@gmail.com     NaN  Applied Data Science
# 2     Johnspinkles  johnspinkles@gmail.com     NaN  Applied Data Science
# 3     Johnspinkles  johnspinkles@gmail.com     NaN  Applied Data Science
# 4     Johnspinkles  johnspinkles@gmail.com     NaN  Applied Data Science
# ...            ...                     ...     ...                   ...
# 1731  Johnspinkles  johnspinkles@gmail.com     NaN                 To-Do
# 1732  Johnspinkles  johnspinkles@gmail.com     NaN                 To-Do
# 1733  Johnspinkles  johnspinkles@gmail.com     NaN                 To-Do
# 1734  Johnspinkles  johnspinkles@gmail.com     NaN                 To-Do
# 1735  Johnspinkles  johnspinkles@gmail.com     NaN                 To-Do
#
#       Task Description Billable  Start date Start time    End date  End time  \
# 0      NaN                   No  2022-01-03   17:39:37  2022-01-03  17:53:45
# 1      NaN                   No  2022-01-04   15:15:58  2022-01-04  15:19:44
# 2      NaN                   No  2022-01-04   15:24:06  2022-01-04  16:40:39
# 3      NaN                   No  2022-01-04   17:17:42  2022-01-04  17:21:43
# 4      NaN                   No  2022-01-04   19:16:30  2022-01-04  19:47:51
# ...    ...         ...      ...         ...        ...         ...       ...
# 1731   NaN           *       No  2022-09-27   21:27:15  2022-09-27  21:38:47
# 1732   NaN           *       No  2022-09-27   21:56:26  2022-09-27  22:06:30
# 1733   NaN           *       No  2022-09-27   22:17:11  2022-09-27  22:22:19
# 1734   NaN      Chores       No  2022-09-27   22:27:57  2022-09-27  22:30:59
# 1735   NaN           *       No  2022-09-27   22:35:11  2022-09-27  22:37:00
#
#       Duration  Tags  Amount ()
# 0     00:14:08   NaN        NaN
# 1     00:03:46   NaN        NaN
# 2     01:16:33   NaN        NaN
# 3     00:04:01   NaN        NaN
# 4     00:31:21   NaN        NaN
# ...        ...   ...        ...
# 1731  00:11:32   NaN        NaN
# 1732  00:10:04   NaN        NaN
# 1733  00:05:08   NaN        NaN
# 1734  00:03:02   NaN        NaN
# 1735  00:01:49   NaN        NaN
#
# [1736 rows x 14 columns]

# %% [markdown]
# ### 🔴 Initial Preprocessing

# %%
# Drop redundant fields
df = df.drop(['User', 'Email', 'Client', 'Billable', 'Amount ()'], axis=1)

# Convert duration string to hours (float)
df['Duration']=pd.to_timedelta(df['Duration']).astype('timedelta64[s]').astype(int) / 3600
df = df.rename(columns={'Duration': 'Duration (hrs)'})

# Combine date
df['Start'] = pd.to_datetime(df['Start date'] + ' ' + df['Start time'], yearfirst=True)
df['End'] = pd.to_datetime(df['End date'] + ' ' + df['End time'], yearfirst=True)

# Drop nans in project. Uncomment these lines to explore nans
# print('NANs in PROJECT: ')
# display(df[df.Project.isna()])
df = df[df.Project.notna()]

# TODO: Remove this after testing and when you have more data. Removes out old projects
df = df[(df.Project != 'Applied Data Science') & (df.Project != 'Statistics for Data Science') & (df.Project != 'Machine Learning 1') & (df.Project != 'MSc Project') & (df.Project != 'ML2') & (df.Project != 'BML') & (df.Project != 'Reinforcement Learning')]

df
# Out:
#      Project  Task Description  Start date Start time    End date  End time  \
# 0      To-Do   NaN              2022-01-03   17:39:37  2022-01-03  17:53:45
# 5      To-Do   NaN              2022-01-05   17:55:39  2022-01-05  18:05:40
# 11     To-Do   NaN              2022-01-06   16:07:41  2022-01-06  16:08:01
# 22     To-Do   NaN              2022-01-07   11:08:26  2022-01-07  11:28:29
# 30     To-Do   NaN              2022-01-10   17:07:26  2022-01-10  17:32:55
# ...      ...   ...         ...         ...        ...         ...       ...
# 1731   To-Do   NaN           *  2022-09-27   21:27:15  2022-09-27  21:38:47
# 1732   To-Do   NaN           *  2022-09-27   21:56:26  2022-09-27  22:06:30
# 1733   To-Do   NaN           *  2022-09-27   22:17:11  2022-09-27  22:22:19
# 1734   To-Do   NaN      Chores  2022-09-27   22:27:57  2022-09-27  22:30:59
# 1735   To-Do   NaN           *  2022-09-27   22:35:11  2022-09-27  22:37:00
#
#       Duration (hrs)  Tags               Start                 End
# 0           0.235556   NaN 2022-01-03 17:39:37 2022-01-03 17:53:45
# 5           0.166944   NaN 2022-01-05 17:55:39 2022-01-05 18:05:40
# 11          0.005556   NaN 2022-01-06 16:07:41 2022-01-06 16:08:01
# 22          0.334167   NaN 2022-01-07 11:08:26 2022-01-07 11:28:29
# 30          0.424722   NaN 2022-01-10 17:07:26 2022-01-10 17:32:55
# ...              ...   ...                 ...                 ...
# 1731        0.192222   NaN 2022-09-27 21:27:15 2022-09-27 21:38:47
# 1732        0.167778   NaN 2022-09-27 21:56:26 2022-09-27 22:06:30
# 1733        0.085556   NaN 2022-09-27 22:17:11 2022-09-27 22:22:19
# 1734        0.050556   NaN 2022-09-27 22:27:57 2022-09-27 22:30:59
# 1735        0.030278   NaN 2022-09-27 22:35:11 2022-09-27 22:37:00
#
# [782 rows x 11 columns]

# %%
print('Unique Projects: ')
for i in range(df.Project.unique().shape[0]):
    print('-', df.Project.unique()[i])
# Out:
# Unique Projects:
# - To-Do
# - Notes
# - Data Science

# %% [markdown]
# ### 🔴 Monthly Preprocessing

# %%
df_monthly = df.copy()
df_monthly = df_monthly.groupby([df_monthly['Start'].dt.month, 'Project']).sum()
df_monthly = df_monthly.reset_index()
df_monthly = df_monthly.drop(['Task', 'Tags'], axis=1)

df_monthly['Start'] = df_monthly['Start'].map(
    { 1 : "January",
       2 : "February",
       3 : "March",
       4 : "April",
       5 : "May",
       6 : "June",
       7 : "July",
       8 : "August",
       9 : "September",
       10 : "October",
       11 : "November",
       12 : "December"})

df_monthly.head(10)
# Out:
#       Start       Project  Duration (hrs)
# 0   January         Notes        2.860833
# 1   January         To-Do       13.160278
# 2  February         Notes        1.210556
# 3  February         To-Do       24.576944
# 4     March         Notes        2.017222
# 5     March         To-Do        7.929722
# 6     April         To-Do        4.455833
# 7       May  Data Science        1.625000
# 8       May         Notes        0.863611
# 9       May         To-Do       12.670833

# %% [markdown]
# ### 🔴 Monthly Breakdown (All vs Academic)
# **All**
# - To-Do
# - Piano
# - Workout
#
# **Academic**
# - Notes
# - Data Science

# %%
# All
df_monthly_all = df_monthly.copy()
for project in df_monthly_all.Project.unique():
    df_monthly_all['Project'].replace(project, 'All', inplace=True)
df_monthly_all = df_monthly_all.groupby('Start', sort=False).sum()
df_monthly_all.reset_index(inplace=True)

# Academic
df_monthly_academic = df_monthly.copy()
df_monthly_academic['Project'].replace('Data Science', 'Academic', inplace=True)
df_monthly_academic['Project'].replace('Notes', 'Academic', inplace=True)
df_monthly_academic = df_monthly_academic[df_monthly_academic['Project'] == 'Academic']
df_monthly_academic = df_monthly_academic.groupby('Start', sort=False).sum()
df_monthly_academic.reset_index(inplace=True)

# %%
from IPython.display import display_html 
df1_styler = df_monthly_all.style.set_table_attributes("style='display:inline'").set_caption('All')
df2_styler = df_monthly_academic.style.set_table_attributes("style='display:inline'").set_caption('Academic')
#df2_t_styler = df2.T.style.set_table_attributes("style='display:inline'").set_caption('df2_t')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_69af6" style='display:inline'>
#   <caption>All</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69af6_level0_col0" class="col_heading level0 col0" >Start</th>
#       <th id="T_69af6_level0_col1" class="col_heading level0 col1" >Duration (hrs)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69af6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69af6_row0_col0" class="data row0 col0" >January</td>
#       <td id="T_69af6_row0_col1" class="data row0 col1" >16.021111</td>
#     </tr>
#     <tr>
#       <th id="T_69af6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69af6_row1_col0" class="data row1 col0" >February</td>
#       <td id="T_69af6_row1_col1" class="data row1 col1" >25.787500</td>
#     </tr>
#     <tr>
#       <th id="T_69af6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69af6_row2_col0" class="data row2 col0" >March</td>
#       <td id="T_69af6_row2_col1" class="data row2 col1" >9.946944</td>
#     </tr>
#     <tr>
#       <th id="T_69af6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69af6_row3_col0" class="data row3 col0" >April</td>
#       <td id="T_69af6_row3_col1" class="data row3 col1" >4.455833</td>
#     </tr>
#     <tr>
#       <th id="T_69af6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69af6_row4_col0" class="data row4 col0" >May</td>
#       <td id="T_69af6_row4_col1" class="data row4 col1" >15.159444</td>
#     </tr>
#     <tr>
#       <th id="T_69af6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_69af6_row5_col0" class="data row5 col0" >June</td>
#       <td id="T_69af6_row5_col1" class="data row5 col1" >34.999722</td>
#     </tr>
#     <tr>
#       <th id="T_69af6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_69af6_row6_col0" class="data row6 col0" >July</td>
#       <td id="T_69af6_row6_col1" class="data row6 col1" >50.733889</td>
#     </tr>
#     <tr>
#       <th id="T_69af6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_69af6_row7_col0" class="data row7 col0" >August</td>
#       <td id="T_69af6_row7_col1" class="data row7 col1" >14.617222</td>
#     </tr>
#     <tr>
#       <th id="T_69af6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_69af6_row8_col0" class="data row8 col0" >September</td>
#       <td id="T_69af6_row8_col1" class="data row8 col1" >71.301389</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_615f6" style='display:inline'>
#   <caption>Academic</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_615f6_level0_col0" class="col_heading level0 col0" >Start</th>
#       <th id="T_615f6_level0_col1" class="col_heading level0 col1" >Duration (hrs)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_615f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_615f6_row0_col0" class="data row0 col0" >January</td>
#       <td id="T_615f6_row0_col1" class="data row0 col1" >2.860833</td>
#     </tr>
#     <tr>
#       <th id="T_615f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_615f6_row1_col0" class="data row1 col0" >February</td>
#       <td id="T_615f6_row1_col1" class="data row1 col1" >1.210556</td>
#     </tr>
#     <tr>
#       <th id="T_615f6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_615f6_row2_col0" class="data row2 col0" >March</td>
#       <td id="T_615f6_row2_col1" class="data row2 col1" >2.017222</td>
#     </tr>
#     <tr>
#       <th id="T_615f6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_615f6_row3_col0" class="data row3 col0" >May</td>
#       <td id="T_615f6_row3_col1" class="data row3 col1" >2.488611</td>
#     </tr>
#     <tr>
#       <th id="T_615f6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_615f6_row4_col0" class="data row4 col0" >June</td>
#       <td id="T_615f6_row4_col1" class="data row4 col1" >7.823333</td>
#     </tr>
#     <tr>
#       <th id="T_615f6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_615f6_row5_col0" class="data row5 col0" >July</td>
#       <td id="T_615f6_row5_col1" class="data row5 col1" >15.629444</td>
#     </tr>
#     <tr>
#       <th id="T_615f6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_615f6_row6_col0" class="data row6 col0" >August</td>
#       <td id="T_615f6_row6_col1" class="data row6 col1" >5.967222</td>
#     </tr>
#     <tr>
#       <th id="T_615f6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_615f6_row7_col0" class="data row7 col0" >September</td>
#       <td id="T_615f6_row7_col1" class="data row7 col1" >35.448333</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 🔴 Monthly Breakdown (Individual Projects)

# %%
figsize=(12,4)
legendsize=10
title_size=20
bar_label_size=17
x_tick_size = 13
y_tick_size = 13

sns.set_theme(style="darkgrid")
plt.figure(figsize=figsize)

# Set your custom color palette https://htmlcolorcodes.com/
unique_projects = df_monthly.Project.unique().shape[0]

colors = {'To-Do': "#FABF2D", 
          'Notes': "#33B2FF", 
          'Data Science': "#332DFA", 
          'Piano': '0FB528', 
          'Workout': 'C01E05'}

hue_order = ['To-Do', 'Data Science', 'Notes']


ax = sns.barplot(x='Start', y='Duration', data=df_monthly, hue='Project', ci=None, palette=colors, hue_order=hue_order)
plt.xlabel('')
plt.ylabel('Time (hrs)', fontsize=15)
plt.title('Total', fontsize=title_size, fontweight='bold')
#ax.bar_label(ax.containers[0], fontsize=bar_label_size, fmt='%.0f', fontweight='bold', label_type='center') # Show values above bars
plt.ylim([0, df_monthly['Duration'].max() + 3])     # Expand y axis range for visibility
ax.xaxis.set_tick_params(labelsize=x_tick_size)                         # Enlarge x ticks
ax.yaxis.set_tick_params(labelsize=y_tick_size)                         # Enlarge x ticks

plt.show()

# %%
## figsize=(12,4)
legendsize=10
title_size=20
bar_label_size=17

sns.set_theme(style="darkgrid")
plt.figure(figsize=figsize)

ax = sns.barplot(x='Project', y='Duration', data=df_monthly, hue='Start', ci=None, palette='PuBuGn')
plt.xlabel('')
plt.ylabel('Time (hrs)', fontsize=15)
plt.title('Total', fontsize=title_size, fontweight='bold')
ax.bar_label(ax.containers[0], fontsize=bar_label_size, fmt='%.0f', fontweight='bold', label_type='center') # Show values above bars
plt.ylim([0, df_monthly['Duration'].max() + 3])     # Expand y axis range for visibility
ax.xaxis.set_tick_params(labelsize=17)                         # Enlarge x ticks
ax.yaxis.set_tick_params(labelsize=13)                         # Enlarge x ticks

plt.show()

# %% [markdown]
# ### 🔴 2. Annual Breakdown

# %%
df_year = df.copy()
df_year = df_year.groupby([df_year['Start'].dt.year, 'Project']).sum()
df_year = df_year.reset_index()
df_year['Duration'] /= 3600

df_year
